# %% [markdown]
# # Ejercicio:  limpieza de json.
#
#
#
# A continuacion tenemos unos datos obtenidos a partir de una api de cilclismo.
# ```python
# response = {'ciclistas': [{'nombre': 'Juan',
#                           'apellido': 'Pérez',
#                           'fecha_nacimiento': '1990-05-15',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 32, 'peso_kg': 70, 'altura_cm': 175}},
#                           {'nombre': 'Maria',
#                           'apellido': 'García',
#                           'fecha_nacimiento': '1985-08-20',
#                           'nacionalidad': 'Mexicana',
#                           'datos_biometricos': {'edad': 37, 'peso_kg': 65, 'altura_cm': 168}},
#                           {'nombre': 'Luis',
#                           'apellido': 'Hernández',
#                           'fecha_nacimiento': '1995-02-10',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 27, 'peso_kg': 68, 'altura_cm': 180}},
#                           {'nombre': 'Ana',
#                           'apellido': 'González',
#                           'fecha_nacimiento': '1992-07-25',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 32, 'peso_kg': 65, 'altura_cm': 165}},
#                           {'nombre': 'José',
#                           'apellido': 'Rodríguez',
#                           'fecha_nacimiento': '1991-09-10',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 31, 'peso_kg': 75, 'altura_cm': 185}},
#                           {'nombre': 'María',
#                           'apellido': 'López',
#                           'fecha_nacimiento': '1993-04-20',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 30, 'peso_kg': 60, 'altura_cm': 160}},
#                           {'nombre': 'Juan',
#                           'apellido': 'Sánchez',
#                           'fecha_nacimiento': '1994-06-15',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 29, 'peso_kg': 70, 'altura_cm': 175}},
#                           {'nombre': 'Alicia',
#                           'apellido': 'García',
#                           'fecha_nacimiento': '1996-08-20',
#                           'nacionalidad': 'Mexicana',
#                           'datos_biometricos': {'edad': 28, 'peso_kg': 65, 'altura_cm': 168}},
#                           {'nombre': 'José',
#                           'apellido': 'Hernández',
#                           'fecha_nacimiento': '1997-02-10',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 27, 'peso_kg': 68, 'altura_cm': 180}},
#                           {'nombre': 'María',
#                           'apellido': 'López',
#                           'fecha_nacimiento': '1998-04-20',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 26, 'peso_kg': 60, 'altura_cm': 160}},
#                           {'nombre': 'Juan',
#                           'apellido': 'Sánchez',
#                           'fecha_nacimiento': '1999-06-15',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 25, 'peso_kg': 70, 'altura_cm': 175}},
#                           {'nombre': 'Alicia',
#                           'apellido': 'García',
#                           'fecha_nacimiento': '2000-08-20',
#                           'nacionalidad': 'Mexicana',
#                           'datos_biometricos': {'edad': 24, 'peso_kg': 65, 'altura_cm': 168}},
#                           {'nombre': 'José',
#                           'apellido': 'Hernández',
#                           'fecha_nacimiento': '2001-02-10',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 23, 'peso_kg': 68, 'altura_cm': 180}},
#                           {'nombre': 'María',
#                           'apellido': 'López',
#                           'fecha_nacimiento': '2002-04-20',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 22, 'peso_kg': 60, 'altura_cm': 160}},
#                           {'nombre': 'Juan',
#                           'apellido': 'Sánchez',
#                           'fecha_nacimiento': '2003-06-15',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 21, 'peso_kg': 70, 'altura_cm': 175}},
#                           {'nombre': 'Alicia',
#                           'apellido': 'García',
#                           'fecha_nacimiento': '2004-08-20',
#                           'nacionalidad': 'Mexicana',
#                           'datos_biometricos': {'edad': 20, 'peso_kg': 65, 'altura_cm': 168}},
#                           {'nombre': 'José',
#                           'apellido': 'Hernández',
#                           'fecha_nacimiento': '2005-02-10',
#                           'nacionalidad': 'Español',
#                           'datos_biometricos': {'edad': 19, 'peso_kg': 68, 'altura_cm': 180}}],
#          'localizaciones': [{'nombre': 'París',
#                             'fecha': '26/06/2022',
#                             'tipo': 'Inicio',
#                             'distancia': '0 km',
#                             'altitud': '0 m'},
#                             {'nombre': 'Roubaix',
#                             'fecha': '27/06/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '200 km',
#                             'altitud': '100 m'},
#                             {'nombre': 'Lille',
#                             'fecha': '28/06/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '180 km',
#                             'altitud': '150 m'},
#                             {'nombre': 'Reims',
#                             'fecha': '29/06/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '220 km',
#                             'altitud': '200 m'},
#                             {'nombre': 'Metz',
#                             'fecha': '30/06/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '250 km',
#                             'altitud': '250 m'},
#                             {'nombre': 'Strasbourg',
#                             'fecha': '01/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '280 km',
#                             'altitud': '300 m'},
#                             {'nombre': 'Mulhouse',
#                             'fecha': '02/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '300 km',
#                             'altitud': '350 m'},
#                             {'nombre': 'Lyon',
#                             'fecha': '03/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '350 km',
#                             'altitud': '400 m'},
#                             {'nombre': 'Grenoble',
#                             'fecha': '04/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '400 km',
#                             'altitud': '450 m'},
#                             {'nombre': 'Toulouse',
#                             'fecha': '05/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '450 km',
#                             'altitud': '500 m'},
#                             {'nombre': 'Pau',
#                             'fecha': '06/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '500 km',
#                             'altitud': '550 m'},
#                             {'nombre': 'Bordeaux',
#                             'fecha': '07/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '550 km',
#                             'altitud': '600 m'},
#                             {'nombre': 'Toulon',
#                             'fecha': '08/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '600 km',
#                             'altitud': '650 m'},
#                             {'nombre': 'Marseille',
#                             'fecha': '09/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '650 km',
#                             'altitud': '700 m'},
#                             {'nombre': 'Niza',
#                             'fecha': '10/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '700 km',
#                             'altitud': '750 m'},
#                             {'nombre': 'Gap',
#                             'fecha': '11/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '750 km',
#                             'altitud': '800 m'},
#                             {'nombre': 'Annecy',
#                             'fecha': '12/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '800 km',
#                             'altitud': '850 m'},
#                             {'nombre': 'Lausana',
#                             'fecha': '13/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '850 km',
#                             'altitud': '900 m'},
#                             {'nombre': 'Ginebra',
#                             'fecha': '14/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '900 km',
#                             'altitud': '950 m'},
#                             {'nombre': 'Zúrich',
#                             'fecha': '15/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '950 km',
#                             'altitud': '1000 m'},
#                             {'nombre': 'Múnich',
#                             'fecha': '16/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1000 km',
#                             'altitud': '1050 m'},
#                             {'nombre': 'Friburgo',
#                             'fecha': '17/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1050 km',
#                             'altitud': '1100 m'},
#                             {'nombre': 'Basilea',
#                             'fecha': '18/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1100 km',
#                             'altitud': '1150 m'},
#                             {'nombre': 'Zurich',
#                             'fecha': '19/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1150 km',
#                             'altitud': '1200 m'},
#                             {'nombre': 'Innsbruck',
#                             'fecha': '20/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1200 km',
#                             'altitud': '1250 m'},
#                             {'nombre': 'Bolzano',
#                             'fecha': '21/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1250 km',
#                             'altitud': '1300 m'},
#                             {'nombre': 'Trento',
#                             'fecha': '22/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1300 km',
#                             'altitud': '1350 m'},
#                             {'nombre': 'Brescia',
#                             'fecha': '23/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1350 km',
#                             'altitud': '1400 m'},
#                             {'nombre': 'Milán',
#                             'fecha': '24/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1400 km',
#                             'altitud': '1450 m'},
#                             {'nombre': 'Turín',
#                             'fecha': '25/07/2022',
#                             'tipo': 'Etapa',
#                             'distancia': '1450 km',
#                             'altitud': '1500 m'}]}
# ```

# %% [markdown]
#  Contesta a las siguinetes preguntas.
#
# > ¿Qué tipo de estructura de datos es response?
#
# > Lista el numero de participantes.
#
# > ¿Qué tipo de estructura de datos es la variable response?
#
# > ¿Cuál es la nacionalidad del primer ciclista?
#
# > ¿Cuál es la fecha de nacimiento del tercer ciclista?
#
# > ¿Cuál es el peso en kg del segundo ciclista?
#
# > ¿Cuál es la altura en cm del último ciclista ?
#
# > Indica el nombre de los ciclisatas que nacieron en el siglo XX.
#
# > ¿Cuántos ciclistas hay?
#
# > ¿Cuál es el nombre completo del cuarto ciclista?
#
# > Genera una lista con el nombre y apellido de cada ciclista.
#
# > ¿Cuál es la edad del quinto ciclista?
#
# > ¿Cuál es el apellido del sexto ciclista?
#
# > ¿Cuál es la nacionalidad del último ciclista?
#
# > ¿Cuál es la edad media de los ciclista ?
#
# > ¿Cuántas localizaciones hay?
#
# > ¿Cuál es el nombre de la primera localización?
#
# > ¿Cuál es la fecha de la segunda localización?
#
# > ¿Cuál es el tipo de la tercera localización?
#
# > ¿Cuál es la distancia de la cuarta localización?
#
# > ¿Cuál es la localización con mayor distancia distancia ?
#
#
# > ¿Cuál es la altitud de la quinta localización?
#
# > ¿Cuál es el nombre de la última localización?
#
# > ¿Cuál es la fecha de la penúltima localización?
#
# > ¿Cuál es el tipo de la antepenúltima localización?
#
# > ¿Cuál es la distancia de la cuarta localización?
